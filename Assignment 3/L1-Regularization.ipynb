# %% [markdown]
# ### Homework 3 - Jeffrey Gong

# %% [markdown]
# ### Part a (L1 Regularization)
#
# #### Introduction
# Used PyTorch for the first time (Used JAX previously). This was an interesting way to learn PyTorch and it was cool to be able to implement my own version of regularization.
#
# #### Results
# As you can see below, I achieved a L2-Relative error of 0.016 < 0.05, after using 100,000 epochs, a learning rate of 0.001, and a l1_lambda of 0.00001.

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# Define the oscillatory function
def f(x):
    result = torch.zeros_like(x)
    result[x < 0] = 5 + sum(torch.sin(k * x[x < 0]) for k in range(1, 5))
    result[x >= 0] = torch.cos(10 * x[x >= 0])
    return result

# %%
# Generate training data
x_train = torch.linspace(-np.pi, np.pi, 80)
y_train = f(x_train) + torch.randn(x_train.size()) * 0.1  # Adding Gaussian noise

# Generate testing data
x_test = torch.linspace(-np.pi, np.pi, 1000)
y_test = f(x_test)

# %%
# Define the neural network
class ReLUNet(nn.Module):
    def __init__(self):
        super(ReLUNet, self).__init__()
        self.fc1 = nn.Linear(1, 50)  # Input layer to hidden layer with 50 neurons
        self.fc2 = nn.Linear(50, 50)  # Hidden layer to another hidden layer with 50 neurons
        self.fc3 = nn.Linear(50, 1)  # Hidden layer to output layer

    def forward(self, x):
        x = torch.relu(self.fc1(x.unsqueeze(1)))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x.squeeze()

# %%
# Instantiate the model, loss function, and optimizer
model = ReLUNet()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
l1_lambda = 0.00001  # Regularization strength
# best so far: 0.00001

# Function for L1 regularization
def l1_regularization(model, loss):
    l1_norm = sum(p.abs().sum() for p in model.parameters())
    loss += l1_lambda * l1_norm
    return loss

# %%
# Train the model
epochs = 100000
for epoch in range(epochs):
    model.train()
    optimizer.zero_grad()
    y_pred = model(x_train)
    loss = criterion(y_pred, y_train)
    loss = l1_regularization(model, loss)  # Apply L1 regularization
    loss.backward()
    optimizer.step()

    if epoch % 500 == 0 or epoch == epochs-1:
        print(f'Epoch {epoch}, Loss: {loss.item()}')
# Out:
# Epoch 0, Loss: 8.764226913452148
# Epoch 500, Loss: 0.2782718241214752
# Epoch 1000, Loss: 0.17133542895317078
# Epoch 1500, Loss: 0.12010836601257324
# Epoch 2000, Loss: 0.08732875436544418
# Epoch 2500, Loss: 0.0655033066868782
# Epoch 3000, Loss: 0.05131649971008301
# Epoch 3500, Loss: 0.04194338247179985
# Epoch 4000, Loss: 0.03606581687927246
# Epoch 4500, Loss: 0.03214931860566139
# Epoch 5000, Loss: 0.029873527586460114
# Epoch 5500, Loss: 0.02694035694003105
# Epoch 6000, Loss: 0.025153154507279396
# Epoch 6500, Loss: 0.024354897439479828
# Epoch 7000, Loss: 0.023468781262636185
# Epoch 7500, Loss: 0.022691641002893448
# Epoch 8000, Loss: 0.021713515743613243
# Epoch 8500, Loss: 0.02313448116183281
# Epoch 9000, Loss: 0.021611884236335754
# Epoch 9500, Loss: 0.01984192430973053
# Epoch 10000, Loss: 0.019190937280654907
# Epoch 10500, Loss: 0.01917617954313755
# Epoch 73500, Loss: 0.014685813337564468
# Epoch 74000, Loss: 0.014770710840821266
# Epoch 74500, Loss: 0.014806876890361309
# Epoch 75000, Loss: 0.014810353517532349
# Epoch 75500, Loss: 0.014876245521008968
# Epoch 76000, Loss: 0.015210339799523354
# Epoch 76500, Loss: 0.01477780006825924
# Epoch 77000, Loss: 0.014713529497385025
# Epoch 77500, Loss: 0.01471170037984848
# Epoch 78000, Loss: 0.01463567279279232
# Epoch 78500, Loss: 0.015005126595497131
# Epoch 79000, Loss: 0.014632081612944603
# Epoch 79500, Loss: 0.014734284952282906
# Epoch 80000, Loss: 0.015102725476026535
# Epoch 80500, Loss: 0.01500600203871727
# Epoch 81000, Loss: 0.01469879038631916
# Epoch 81500, Loss: 0.01570039428770542
# Epoch 82000, Loss: 0.01472198124974966
# Epoch 82500, Loss: 0.014804973267018795
# Epoch 83000, Loss: 0.015231136232614517
# Epoch 83500, Loss: 0.014579979702830315
# Epoch 84000, Loss: 0.014669874683022499
# Epoch 84500, Loss: 0.014629477635025978
# Epoch 85000, Loss: 0.015458810143172741
# Epoch 85500, Loss: 0.014563344419002533
# Epoch 86000, Loss: 0.014737257733941078
# Epoch 86500, Loss: 0.015319449827075005
# Epoch 87000, Loss: 0.014647151343524456
# Epoch 87500, Loss: 0.016155537217855453
# Epoch 88000, Loss: 0.014714440330862999
# Epoch 88500, Loss: 0.014982111752033234
# Epoch 89000, Loss: 0.014702620916068554
# Epoch 89500, Loss: 0.01514847669750452
# Epoch 90000, Loss: 0.015079899691045284
# Epoch 90500, Loss: 0.014509223401546478
# Epoch 91000, Loss: 0.014750002883374691
# Epoch 91500, Loss: 0.01678900234401226
# Epoch 92000, Loss: 0.014916145242750645
# Epoch 92500, Loss: 0.01453949511051178
# Epoch 93000, Loss: 0.014523245394229889
# Epoch 93500, Loss: 0.014571283012628555
# Epoch 94000, Loss: 0.014562983997166157
# Epoch 94500, Loss: 0.01569485105574131
# Epoch 95000, Loss: 0.01469317264854908
# Epoch 95500, Loss: 0.014643704518675804
# Epoch 96000, Loss: 0.01463084015995264
# Epoch 96500, Loss: 0.014481420628726482
# Epoch 97000, Loss: 0.01445484347641468
# Epoch 97500, Loss: 0.014716282486915588
# Epoch 98000, Loss: 0.014572333544492722
# Epoch 98500, Loss: 0.014449268579483032
# Epoch 99000, Loss: 0.014649848453700542
# Epoch 99500, Loss: 0.015227489173412323
# Epoch 99999, Loss: 0.014515030197799206

# %%
# Calculate L2 relative error
model.eval()
with torch.no_grad():
    y_pred_test = model(x_test)
    l2_norm = torch.sqrt(torch.sum((y_pred_test - y_test) ** 2))
    f_norm = torch.sqrt(torch.sum(y_test ** 2))
    l2_relative_error = l2_norm / f_norm
    print(f'L2 Relative Error: {l2_relative_error.item()}')
# Out:
# L2 Relative Error: 0.016352219507098198
